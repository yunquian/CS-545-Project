# %%
# % cd..
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np

from scipy import signal
from scipy.signal import stft
from scipy.io import wavfile

import matplotlib.pyplot as plt

from env import *
from visualization import plot_spec

plt.style.use({'figure.facecolor':'white'})

# %%
from scipy.fft import dct
from data import AudioData
from data import read_audio
from data.transform import db_to_amp, log_stft
from data.metadata import vcc

meta_data = vcc.VCC2016TrainAppendedMetadata()

dat = []

for speaker_id in range(8):
    for audio_id in range(2):
       dat.append(AudioData(meta_data.get(speaker_id, audio_id)))

# %%
def plot_audio_dat(audio_data:AudioData):
    plot_spec(log_stft(audio_data.amp), freq=freq, title='Log spec')
    plt.twinx()
    plt.plot(audio_data.selected_frames)
    # plt.plot(audio_data.frame_energy)

for item in dat:
    plot_audio_dat(item)
