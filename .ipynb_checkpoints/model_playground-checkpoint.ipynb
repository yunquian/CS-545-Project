# %%
# %load_ext autoreload
# %autoreload 2

# %%
from datetime import datetime

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch import optim

from dataset import MetaDataset
from metadata.vcc import SanityMetadata

from models import save_model, load_model
from models.vae import ToyVAE
from maml import reptile_train

# %%
dataset = MetaDataset(SanityMetadata())
dataset.read_and_preprocess()
print('Data loaded', datetime.now())
# Out:
# Data loaded 2021-11-20 01:40:27.578299

# %%
device = torch.device('cpu')
model = ToyVAE()

# def criterion(recon_y, y, mu, log_var):
#     BCE = F.binary_cross_entropy(recon_y, y, reduction='sum')
#     # BCE = F.binary_cross_entropy(recon_x, x.view(-1, 784),
#     #                              reduce=True, size_average=False)
#     print("BCE is:", BCE)
#     KLD = -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())
#     print("KLD is:", KLD)
#     return BCE + KLD
#     # return BCE

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3, weight_decay=0.0)


def train(trained_model, x, y, n_inner_loop=8):
    trained_model.train()
    x = torch.transpose(x, 0, 1)
    x = nn.functional.normalize(x)
#     x = x - torch.mean(x)
    y = torch.transpose(y, 0, 1)
    y = nn.functional.normalize(y)
#     y = y - torch.mean(y)
    x = x.to(device)
    y = y.to(device)
    for _ in range(n_inner_loop):
        optimizer.zero_grad()
        out_tuple = trained_model(x)
        out = out_tuple[0]
        mu = out_tuple[1]
        log_var = out_tuple[2]
#         loss = criterion(out, y, mu, log_var)
        loss = criterion(out, y)
        loss.backward()
        optimizer.step()
    print(loss.item(), end='')

# %%
# Meta train

reptile_train(model, dataset, n_shot=None, n_iter_outer=100,
              outer_step_size=1e-1, inner_train_func=train)
save_model('saved_models/temp.pt', model)
# Out:
# Iter 0: nan
# Iter 1: nan
# Iter 2: nan
# Iter 3: nan
# Iter 4: nan
# Iter 5: nan
# Iter 6: nan
# Iter 7: nan
# Iter 8: nan
# Iter 9: nan
# Iter 10: nan
# Iter 11: nan
# Iter 12: nan
# Iter 13: nan
# Iter 14: nan
# Iter 15: nan
# Iter 16: nan
# Iter 17: nan
# Iter 18: nan
# Iter 19: nan
# Iter 20: nan
# Iter 21: nan
# Iter 22: nan
# Iter 23: nan
# Iter 24: nan
# Iter 25: nan
# Iter 26: nan
# Iter 27: nan
# Iter 28: nan
# Iter 29: nan
# Iter 30: nan
# Iter 31: nan
# Iter 32: nan
# Iter 33: nan
# Iter 34: nan
# Iter 35: nan
# Iter 36: nan
# Iter 37: nan
# Iter 38: nan
# Iter 39: nan
# Iter 40: nan
# Iter 41: nan
# Iter 42: nan
# Iter 43: nan
# Iter 44: nan
# Iter 45: nan
# Iter 46: nan
# Iter 47: nan
# Iter 48: nan
# Iter 49: nan
# Iter 50: nan
# Iter 51: nan
# Iter 52: nan
# Iter 53: nan
# Iter 54: nan
# Iter 55: nan
# Iter 56: nan
# Iter 57: nan
# Iter 58: nan
# Iter 59: nan
# Iter 60: nan
# Iter 61: nan
# Iter 62: nan
# Iter 63: nan
# Iter 64: nan
# Iter 65: nan
# Iter 66: nan
# Iter 67: nan
# Iter 68: nan
# Iter 69: nan
# Iter 70: nan
# Iter 71: nan
# Iter 72: nan
# Iter 73: nan
# Iter 74: nan
# Iter 75: nan
# Iter 76: nan
# Iter 77: nan
# Iter 78: nan
# Iter 79: nan
# Iter 80: nan
# Iter 81: nan
# Iter 82: nan
# Iter 83: nan
# Iter 84: nan
# Iter 85: nan
# Iter 86: nan
# Iter 87: nan
# Iter 88: nan
# Iter 89: nan
# Iter 90: nan
# Iter 91: nan
# Iter 92: nan
# Iter 93: nan
# Iter 94: nan
# Iter 95: nan
# Iter 96: nan
# Iter 97: nan
# Iter 98: nan
# Iter 99: nan

# %%
# Second train after meta training

pretrained_model = load_model('saved_models/temp.pt', ToyVAE)

# %%
import numpy as np
import matplotlib.pyplot as plt

from env import sr
from transform import log_stft, db_to_amp
from dataset import read_audio, TaskDataset, InputData
from visualization import plot_spec
from vocoder import griffin_lim


def sound(x, rate=sr, label=''):
    from IPython.display import display, Audio, HTML
    display(HTML(
        '<style> table, th, td {border: 0px; }</style> <table><tr><td>'
        + label + '</td><td>' + Audio(x, rate=rate)._repr_html_()[3:]
        + '</td></tr></table>'
    ))


def test(c, train_source_filename, train_target_filename,
         test_input_filename):
    def plot_selected_frames(selected_frames):
        plt.twinx()
        plt.scatter(np.arange(selected_frames.size), selected_frames)

    task_dat = TaskDataset(train_source_filename, train_target_filename)
    input_dat = InputData(test_input_filename)
    plot_spec(log_stft(task_dat.source.amp), title='Source train')
    plot_selected_frames(task_dat.source.selected_frames)
    sound(read_audio(train_source_filename), label='Source train')
    plot_spec(log_stft(task_dat.target.amp), title='Target train')
    plot_selected_frames(task_dat.target.selected_frames)
    sound(read_audio(train_target_filename), label='Target train')

    train_x, train_y = task_dat.get()
    plot_spec(train_x, title='Source train aligned')
    sound(griffin_lim(db_to_amp(train_x)), label='Source train aligned')

    plot_spec(train_y, title='Target train aligned')
    sound(griffin_lim(db_to_amp(train_y)), label='Target train aligned')

    train_x, train_y = torch.from_numpy(train_x), torch.from_numpy(train_y)
    train(model, train_x, train_y, n_inner_loop=20)

    x = input_dat.get()
    x = torch.from_numpy(x.T)
    estimated_tuple = model(x)
    estimated = estimated_tuple[0]
    y = estimated.detach().numpy().T
    plot_spec(log_stft(input_dat.dat.amp), title='Test source')
    sound(read_audio(test_input_filename), label='Test source')
    plot_spec(y, title='Test output')
    sound(griffin_lim(db_to_amp(y)), label='Test source')


meta_dat = SanityMetadata()

test(pretrained_model, meta_dat.get(0, 0), meta_dat.get(1, 0),
     meta_dat.get(0, 1))
# Out:
# <style> table, th, td {border: 0px; }</style> <table><tr><td>Source train</td><td>              <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#               </td></tr></table>
# <style> table, th, td {border: 0px; }</style> <table><tr><td>Target train</td><td>              <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#               </td></tr></table>
# <style> table, th, td {border: 0px; }</style> <table><tr><td>Source train aligned</td><td>              <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#               </td></tr></table>
# <style> table, th, td {border: 0px; }</style> <table><tr><td>Target train aligned</td><td>              <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#               </td></tr></table>
# nan
# <style> table, th, td {border: 0px; }</style> <table><tr><td>Test source</td><td>              <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#               </td></tr></table>
# ---------------------------------------------------------------------------
# ParameterError                            Traceback (most recent call last)
# <ipython-input-7-af609004bff1> in <module>
#      56 meta_dat = SanityMetadata()
#      57
# ---> 58 test(pretrained_model, meta_dat.get(0, 0), meta_dat.get(1, 0),
#      59      meta_dat.get(0, 1))
#
# <ipython-input-7-af609004bff1> in test(c, train_source_filename, train_target_filename, test_input_filename)
#      51     sound(read_audio(test_input_filename), label='Test source')
#      52     plot_spec(y, title='Test output')
# ---> 53     sound(griffin_lim(db_to_amp(y)), label='Test source')
#      54
#      55
#
# ~\OneDrive\Desktop\UIUC\Fall2021\CS545\FinalProject\VoiceTransfer\vocoder.py in griffin_lim(amp)
#      10
#      11 def griffin_lim(amp):
# ---> 12     return librosa.feature.inverse.griffinlim(
#      13         amp, hop_length=n_fft // 2, win_length=n_fft,
#      14         n_iter=500)
#
# ~\anaconda3\lib\site-packages\librosa\core\spectrum.py in griffinlim(S, n_iter, hop_length, win_length, window, center, dtype, length, pad_mode, momentum, init, random_state)
#    2406
#    2407         # Rebuild the spectrogram
# -> 2408         rebuilt = stft(
#    2409             inverse,
#    2410             n_fft=n_fft,
#
# ~\anaconda3\lib\site-packages\librosa\core\spectrum.py in stft(y, n_fft, hop_length, win_length, window, center, dtype, pad_mode)
#     215
#     216     # Check audio is valid
# --> 217     util.valid_audio(y)
#     218
#     219     # Pad the time series so that frames are centered
#
# ~\anaconda3\lib\site-packages\librosa\util\utils.py in valid_audio(y, mono)
#     308
#     309     if not np.isfinite(y).all():
# --> 310         raise ParameterError("Audio buffer is not finite everywhere")
#     311
#     312     return True
#
# ParameterError: Audio buffer is not finite everywhere

# %%
# test with actual samples
