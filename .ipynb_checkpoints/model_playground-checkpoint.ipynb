# %%
# %load_ext autoreload
# %autoreload 2

# %%
from datetime import datetime

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch import optim

from dataset import MetaDataset
from metadata.vcc import SanityMetadata

from models import save_model, load_model
from models.vae import ToyVAE
from maml import reptile_train

# %%
dataset = MetaDataset(SanityMetadata())
dataset.read_and_preprocess()
print('Data loaded', datetime.now())
# Out:
# Data loaded 2021-11-20 00:43:58.585629

# %%
device = torch.device('cpu')
model = ToyVAE()

def criterion(recon_y, y, mu, log_var):
    BCE = F.binary_cross_entropy(recon_y, y, reduction='sum')
    # BCE = F.binary_cross_entropy(recon_x, x.view(-1, 784),
    #                              reduce=True, size_average=False)
    print("BCE is:", BCE)
    KLD = -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())
    print("KLD is:", KLD)
    return BCE + KLD
    # return BCE

optimizer = optim.Adam(model.parameters(), lr=1e-3, weight_decay=0.0)


def train(trained_model, x, y, n_inner_loop=8):
    trained_model.train()
    x = torch.transpose(x, 0, 1)
    y = torch.transpose(y, 0, 1)
    x = x.to(device)
    y = y.to(device)
    for _ in range(n_inner_loop):
        optimizer.zero_grad()
        out_tuple = trained_model(x)
        out = out_tuple[0]
        mu = out_tuple[1]
        log_var = out_tuple[2]
        loss = criterion(out, y, mu, log_var)
        loss.backward()
        optimizer.step()
    print(loss.item(), end='')

# %%
# Meta train

reptile_train(model, dataset, n_shot=None, n_iter_outer=100,
              outer_step_size=1e-1, inner_train_func=train)
save_model('saved_models/temp.pt', model)
# Out:
# Iter 0: BCE is: tensor(1855364.7500, grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(816991.6875, grad_fn=<MulBackward0>)
# BCE is: tensor(-14797340., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3.0831e+20, grad_fn=<MulBackward0>)
# BCE is: tensor(-21378200., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3.3303e+15, grad_fn=<MulBackward0>)
# BCE is: tensor(-4036582.5000, grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(790411.0625, grad_fn=<MulBackward0>)
# BCE is: tensor(-31033938., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1.4736e+11, grad_fn=<MulBackward0>)
# BCE is: tensor(-14705830., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3.5501e+12, grad_fn=<MulBackward0>)
# BCE is: tensor(-25996664., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(4.9690e+10, grad_fn=<MulBackward0>)
# BCE is: tensor(-40157120., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(8.9418e+08, grad_fn=<MulBackward0>)
# 854027456.0
# Iter 1: BCE is: tensor(-1322163.5000, grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1.4768e+08, grad_fn=<MulBackward0>)
# BCE is: tensor(-2137392.5000, grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(50694956., grad_fn=<MulBackward0>)
# BCE is: tensor(-6380055.5000, grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(5.7517e+10, grad_fn=<MulBackward0>)
# BCE is: tensor(-8499159., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2.2503e+10, grad_fn=<MulBackward0>)
# BCE is: tensor(-6606104., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(52264944., grad_fn=<MulBackward0>)
# BCE is: tensor(-7420805., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(327020.3750, grad_fn=<MulBackward0>)
# BCE is: tensor(-13588225., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(314620.0312, grad_fn=<MulBackward0>)
# BCE is: tensor(-20427872., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(402507.1875, grad_fn=<MulBackward0>)
# -20025364.0
# Iter 2: BCE is: tensor(-2642328.5000, grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(4.4446e+08, grad_fn=<MulBackward0>)
# BCE is: tensor(-4327721., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1.0308e+08, grad_fn=<MulBackward0>)
# BCE is: tensor(-4939156., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(28242552., grad_fn=<MulBackward0>)
# BCE is: tensor(-6023927.5000, grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(8368874.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-9198889., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2990816.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-13814941., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1337693., grad_fn=<MulBackward0>)
# BCE is: tensor(-17101858., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(775908.0625, grad_fn=<MulBackward0>)
# BCE is: tensor(-23982700., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(574051.1875, grad_fn=<MulBackward0>)
# -23408648.0
# Iter 3: BCE is: tensor(-2511590.2500, grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(62815100., grad_fn=<MulBackward0>)
# BCE is: tensor(-3957481.5000, grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(28846530., grad_fn=<MulBackward0>)
# BCE is: tensor(-5045998.5000, grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(13804159., grad_fn=<MulBackward0>)
# BCE is: tensor(-4889045., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(7515615.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-7500847., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(4330601., grad_fn=<MulBackward0>)
# BCE is: tensor(-12423304., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2821871.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-16042208., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2025829.2500, grad_fn=<MulBackward0>)
# BCE is: tensor(-22704422., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1496507.6250, grad_fn=<MulBackward0>)
# -21207914.0
# Iter 4: BCE is: tensor(-4063425.5000, grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(40378580., grad_fn=<MulBackward0>)
# BCE is: tensor(-4035602.2500, grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(26712166., grad_fn=<MulBackward0>)
# BCE is: tensor(-7964762., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(18124652., grad_fn=<MulBackward0>)
# BCE is: tensor(-8840570., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(12806097., grad_fn=<MulBackward0>)
# BCE is: tensor(-12012435., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(9622944., grad_fn=<MulBackward0>)
# BCE is: tensor(-15201361., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(7368905., grad_fn=<MulBackward0>)
# BCE is: tensor(-20167968., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(5701609., grad_fn=<MulBackward0>)
# BCE is: tensor(-25288606., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(4547273., grad_fn=<MulBackward0>)
# -20741332.0
# Iter 5: BCE is: tensor(-3998211.7500, grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(240587.3750, grad_fn=<MulBackward0>)
# BCE is: tensor(-4055431.7500, grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(225977.8281, grad_fn=<MulBackward0>)
# BCE is: tensor(-5586389., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(219013.6875, grad_fn=<MulBackward0>)
# BCE is: tensor(-8536786., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(218976.9844, grad_fn=<MulBackward0>)
# BCE is: tensor(-14348544., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(225121.5312, grad_fn=<MulBackward0>)
# BCE is: tensor(-19230140., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(237049.2344, grad_fn=<MulBackward0>)
# BCE is: tensor(-26748784., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(255176.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-33446174., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(279004.8438, grad_fn=<MulBackward0>)
# -33167170.0
# Iter 6: BCE is: tensor(-4300416.5000, grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(713993., grad_fn=<MulBackward0>)
# BCE is: tensor(-7351675., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(693739.5625, grad_fn=<MulBackward0>)
# BCE is: tensor(-7867651.5000, grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(676692.6250, grad_fn=<MulBackward0>)
# BCE is: tensor(-14257203., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(663204.3125, grad_fn=<MulBackward0>)
# BCE is: tensor(-17847200., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(653687.5625, grad_fn=<MulBackward0>)
# BCE is: tensor(-24099764., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(649387.0625, grad_fn=<MulBackward0>)
# BCE is: tensor(-30174072., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(650027.8750, grad_fn=<MulBackward0>)
# BCE is: tensor(-36072168., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(654329., grad_fn=<MulBackward0>)
# -35417840.0
# Iter 7: BCE is: tensor(-6704549., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(702347.4375, grad_fn=<MulBackward0>)
# BCE is: tensor(-7435800., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(693190.5625, grad_fn=<MulBackward0>)
# BCE is: tensor(-10985208., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(687738.3750, grad_fn=<MulBackward0>)
# BCE is: tensor(-17418048., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(685987.8125, grad_fn=<MulBackward0>)
# BCE is: tensor(-23631148., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(689129.2500, grad_fn=<MulBackward0>)
# BCE is: tensor(-29839464., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(696040.4375, grad_fn=<MulBackward0>)
# BCE is: tensor(-36588548., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(704097.0625, grad_fn=<MulBackward0>)
# BCE is: tensor(-39856716., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(713474.1875, grad_fn=<MulBackward0>)
# -39143240.0
# Iter 8: BCE is: tensor(-11062268., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3594934.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-13721896., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3527844.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-17798912., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3465348.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-25141464., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3410244.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-29097080., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3361809.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-33151448., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3318331., grad_fn=<MulBackward0>)
# BCE is: tensor(-35579936., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3278884.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-36959288., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3241605.5000, grad_fn=<MulBackward0>)
# -33717684.0
# Iter 9: BCE is: tensor(-4459880.5000, grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(211995.0781, grad_fn=<MulBackward0>)
# BCE is: tensor(-4906605., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(228114.9062, grad_fn=<MulBackward0>)
# BCE is: tensor(-12042724., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(252393.0625, grad_fn=<MulBackward0>)
# BCE is: tensor(-19663604., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(288124.1562, grad_fn=<MulBackward0>)
# BCE is: tensor(-30811460., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(337458.8125, grad_fn=<MulBackward0>)
# BCE is: tensor(-40995740., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(400918.2188, grad_fn=<MulBackward0>)
# BCE is: tensor(-52150584., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(479796.2500, grad_fn=<MulBackward0>)
# BCE is: tensor(-65171264., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(573116.4375, grad_fn=<MulBackward0>)
# -64598148.0
# Iter 10: BCE is: tensor(-9852866., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(638821.5625, grad_fn=<MulBackward0>)
# BCE is: tensor(-11498188., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(643366.1250, grad_fn=<MulBackward0>)
# BCE is: tensor(-14069478., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(649211.1250, grad_fn=<MulBackward0>)
# BCE is: tensor(-17365240., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(656194.8750, grad_fn=<MulBackward0>)
# BCE is: tensor(-21285056., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(664201.6250, grad_fn=<MulBackward0>)
# BCE is: tensor(-24798186., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(672796.3125, grad_fn=<MulBackward0>)
# BCE is: tensor(-27858496., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(681601.5625, grad_fn=<MulBackward0>)
# BCE is: tensor(-29386714., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(690153.4375, grad_fn=<MulBackward0>)
# -28696560.0
# Iter 11: BCE is: tensor(-15042147., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2519253.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-18075428., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2482432.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-20561632., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2438332., grad_fn=<MulBackward0>)
# BCE is: tensor(-25290300., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2390268., grad_fn=<MulBackward0>)
# BCE is: tensor(-28138220., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2338395., grad_fn=<MulBackward0>)
# BCE is: tensor(-31710166., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2284436., grad_fn=<MulBackward0>)
# BCE is: tensor(-34091464., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2229204.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-37740856., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2173670.2500, grad_fn=<MulBackward0>)
# -35567184.0
# Iter 12: BCE is: tensor(-14800820., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(268518.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-18928704., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(277524.1250, grad_fn=<MulBackward0>)
# BCE is: tensor(-24045812., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(289816.6875, grad_fn=<MulBackward0>)
# BCE is: tensor(-30414066., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(304775.6562, grad_fn=<MulBackward0>)
# BCE is: tensor(-35328200., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(321671.2188, grad_fn=<MulBackward0>)
# BCE is: tensor(-39630660., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(339706.2812, grad_fn=<MulBackward0>)
# BCE is: tensor(-42870428., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(357954.2500, grad_fn=<MulBackward0>)
# BCE is: tensor(-44929768., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(375843.7500, grad_fn=<MulBackward0>)
# -44553924.0
# Iter 13: BCE is: tensor(-9682805., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2050848., grad_fn=<MulBackward0>)
# BCE is: tensor(-11522238., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2032806.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-13120597., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2009780.6250, grad_fn=<MulBackward0>)
# BCE is: tensor(-14309610., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1982777.6250, grad_fn=<MulBackward0>)
# BCE is: tensor(-15589404., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1952996.2500, grad_fn=<MulBackward0>)
# BCE is: tensor(-16545125., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1921176.3750, grad_fn=<MulBackward0>)
# BCE is: tensor(-17256226., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1887948.1250, grad_fn=<MulBackward0>)
# BCE is: tensor(-17518930., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1853633.8750, grad_fn=<MulBackward0>)
# -15665296.0
# Iter 14: BCE is: tensor(-19986786., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(298044.5312, grad_fn=<MulBackward0>)
# BCE is: tensor(-23929932., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(304828.0625, grad_fn=<MulBackward0>)
# BCE is: tensor(-27176194., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(314107.3125, grad_fn=<MulBackward0>)
# BCE is: tensor(-31552732., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(325435.4375, grad_fn=<MulBackward0>)
# BCE is: tensor(-36662516., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(338319.7812, grad_fn=<MulBackward0>)
# BCE is: tensor(-40459320., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(352315., grad_fn=<MulBackward0>)
# BCE is: tensor(-42280856., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(367072.5938, grad_fn=<MulBackward0>)
# BCE is: tensor(-45025240., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(382618.5000, grad_fn=<MulBackward0>)
# -44642620.0
# Iter 15: BCE is: tensor(-20818104., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(694612.2500, grad_fn=<MulBackward0>)
# BCE is: tensor(-22343644., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(698166.5625, grad_fn=<MulBackward0>)
# BCE is: tensor(-24726098., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(702852.1875, grad_fn=<MulBackward0>)
# BCE is: tensor(-27477650., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(708146.6250, grad_fn=<MulBackward0>)
# BCE is: tensor(-29659528., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(713699., grad_fn=<MulBackward0>)
# BCE is: tensor(-32930504., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(719389.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-35051804., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(725210.9375, grad_fn=<MulBackward0>)
# BCE is: tensor(-37423104., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(730993.6875, grad_fn=<MulBackward0>)
# -36692112.0
# Iter 16: BCE is: tensor(-22061634., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2387835., grad_fn=<MulBackward0>)
# BCE is: tensor(-26538490., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2361585.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-31187152., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2327776.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-34301284., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2288030.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-37168616., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2243292., grad_fn=<MulBackward0>)
# BCE is: tensor(-39159168., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2194663.2500, grad_fn=<MulBackward0>)
# BCE is: tensor(-41250424., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2142974.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-42446660., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2088881., grad_fn=<MulBackward0>)
# -40357780.0
# Iter 17: BCE is: tensor(-8358114., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(78459.1328, grad_fn=<MulBackward0>)
# BCE is: tensor(-8709571., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(80346.7656, grad_fn=<MulBackward0>)
# BCE is: tensor(-10009812., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(82683.8125, grad_fn=<MulBackward0>)
# BCE is: tensor(-10434947., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(85250.5312, grad_fn=<MulBackward0>)
# BCE is: tensor(-12420346., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(89092.8438, grad_fn=<MulBackward0>)
# BCE is: tensor(-12563842., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(100277.0781, grad_fn=<MulBackward0>)
# BCE is: tensor(-14068220., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(164954.4844, grad_fn=<MulBackward0>)
# BCE is: tensor(-14931855., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(273580.6562, grad_fn=<MulBackward0>)
# -14658274.0
# Iter 18: BCE is: tensor(-36797780., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1658811.2500, grad_fn=<MulBackward0>)
# BCE is: tensor(-40733428., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1681493.8750, grad_fn=<MulBackward0>)
# BCE is: tensor(-47274832., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1721874.8750, grad_fn=<MulBackward0>)
# BCE is: tensor(-55215108., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1778892.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-63613052., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1849911., grad_fn=<MulBackward0>)
# BCE is: tensor(-73601744., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1929457.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-87355320., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2013525.3750, grad_fn=<MulBackward0>)
# BCE is: tensor(-97459088., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2097938.2500, grad_fn=<MulBackward0>)
# -95361152.0
# Iter 19: BCE is: tensor(-11117226., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(179859.1562, grad_fn=<MulBackward0>)
# BCE is: tensor(-11548262., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(184807.8438, grad_fn=<MulBackward0>)
# BCE is: tensor(-12225048., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(190242.5312, grad_fn=<MulBackward0>)
# BCE is: tensor(-12586427., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(195854.2656, grad_fn=<MulBackward0>)
# BCE is: tensor(-13594446., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(201611.6719, grad_fn=<MulBackward0>)
# BCE is: tensor(-14339092., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(207241.3594, grad_fn=<MulBackward0>)
# BCE is: tensor(-14119952., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(212625.4531, grad_fn=<MulBackward0>)
# BCE is: tensor(-15110440., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(217676.1094, grad_fn=<MulBackward0>)
# -14892764.0
# Iter 20: BCE is: tensor(-14163639., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(243129.1719, grad_fn=<MulBackward0>)
# BCE is: tensor(-14561093., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(245480.7969, grad_fn=<MulBackward0>)
# BCE is: tensor(-15249858., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(247866.7812, grad_fn=<MulBackward0>)
# BCE is: tensor(-15820219., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(250225.1719, grad_fn=<MulBackward0>)
# BCE is: tensor(-16426850., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(252509.2500, grad_fn=<MulBackward0>)
# BCE is: tensor(-16960512., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(254655.3125, grad_fn=<MulBackward0>)
# BCE is: tensor(-17210930., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(256607.8438, grad_fn=<MulBackward0>)
# BCE is: tensor(-17362124., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(258339.1875, grad_fn=<MulBackward0>)
# -17103784.0
# Iter 21: BCE is: tensor(-29383676., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(23953168., grad_fn=<MulBackward0>)
# BCE is: tensor(-30278952., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(23404124., grad_fn=<MulBackward0>)
# BCE is: tensor(-31744126., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(22448344., grad_fn=<MulBackward0>)
# BCE is: tensor(-32374894., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(21193536., grad_fn=<MulBackward0>)
# BCE is: tensor(-33991044., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(19752386., grad_fn=<MulBackward0>)
# BCE is: tensor(-34289632., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(18222664., grad_fn=<MulBackward0>)
# BCE is: tensor(-34362928., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(16682295., grad_fn=<MulBackward0>)
# BCE is: tensor(-34742104., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(15188545., grad_fn=<MulBackward0>)
# -19553560.0
# Iter 22: BCE is: tensor(-33032980., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(214074.2969, grad_fn=<MulBackward0>)
# BCE is: tensor(-34407152., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(220136.0938, grad_fn=<MulBackward0>)
# BCE is: tensor(-36872260., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(228941.2344, grad_fn=<MulBackward0>)
# BCE is: tensor(-39277432., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(240714.5156, grad_fn=<MulBackward0>)
# BCE is: tensor(-42365460., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(255602.9844, grad_fn=<MulBackward0>)
# BCE is: tensor(-44629160., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(273787.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-47046528., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(295441.6250, grad_fn=<MulBackward0>)
# BCE is: tensor(-49658108., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(319896.0625, grad_fn=<MulBackward0>)
# -49338212.0
# Iter 23: BCE is: tensor(-32294124., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(275185.9375, grad_fn=<MulBackward0>)
# BCE is: tensor(-34375256., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(280589.1562, grad_fn=<MulBackward0>)
# BCE is: tensor(-36267000., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(287333.9062, grad_fn=<MulBackward0>)
# BCE is: tensor(-38098120., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(294933.7188, grad_fn=<MulBackward0>)
# BCE is: tensor(-40260592., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(302920.0625, grad_fn=<MulBackward0>)
# BCE is: tensor(-41258872., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(311005.3125, grad_fn=<MulBackward0>)
# BCE is: tensor(-41885528., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(318668.5625, grad_fn=<MulBackward0>)
# BCE is: tensor(-43321712., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(325620.6875, grad_fn=<MulBackward0>)
# -42996092.0
# Iter 24: BCE is: tensor(-31634884., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2053990.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-34033800., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2007956.1250, grad_fn=<MulBackward0>)
# BCE is: tensor(-34827292., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1958643.3750, grad_fn=<MulBackward0>)
# BCE is: tensor(-36171888., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1907192.6250, grad_fn=<MulBackward0>)
# BCE is: tensor(-38551344., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1854518.1250, grad_fn=<MulBackward0>)
# BCE is: tensor(-39661376., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1801441.3750, grad_fn=<MulBackward0>)
# BCE is: tensor(-41495296., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1748616.1250, grad_fn=<MulBackward0>)
# BCE is: tensor(-42679540., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1696482.2500, grad_fn=<MulBackward0>)
# -40983056.0
# Iter 25: BCE is: tensor(-31992340., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1783494.1250, grad_fn=<MulBackward0>)
# BCE is: tensor(-32296760., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1759757.6250, grad_fn=<MulBackward0>)
# BCE is: tensor(-33209272., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1737631.1250, grad_fn=<MulBackward0>)
# BCE is: tensor(-35989172., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1716984.6250, grad_fn=<MulBackward0>)
# BCE is: tensor(-36674824., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1697424.8750, grad_fn=<MulBackward0>)
# BCE is: tensor(-37502208., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1678745.2500, grad_fn=<MulBackward0>)
# BCE is: tensor(-38832152., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1660703.6250, grad_fn=<MulBackward0>)
# BCE is: tensor(-39447384., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1643085., grad_fn=<MulBackward0>)
# -37804300.0
# Iter 26: BCE is: tensor(-39593748., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3360227.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-41966996., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3323689.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-43635856., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3283365.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-44236736., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3241502.2500, grad_fn=<MulBackward0>)
# BCE is: tensor(-45446688., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3198170.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-46872768., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3152883.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-46615900., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3105869., grad_fn=<MulBackward0>)
# BCE is: tensor(-48641052., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3057959.5000, grad_fn=<MulBackward0>)
# -45583092.0
# Iter 27: BCE is: tensor(-32197436., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(56912192., grad_fn=<MulBackward0>)
# BCE is: tensor(-33778384., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(53703676., grad_fn=<MulBackward0>)
# BCE is: tensor(-33092340., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(48986012., grad_fn=<MulBackward0>)
# BCE is: tensor(-33865064., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(43508328., grad_fn=<MulBackward0>)
# BCE is: tensor(-34352904., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(37889380., grad_fn=<MulBackward0>)
# BCE is: tensor(-34608952., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(32552754., grad_fn=<MulBackward0>)
# BCE is: tensor(-34813872., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(27735974., grad_fn=<MulBackward0>)
# BCE is: tensor(-35020200., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(23535380., grad_fn=<MulBackward0>)
# -11484820.0
# Iter 28: BCE is: tensor(-34815124., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1824784.1250, grad_fn=<MulBackward0>)
# BCE is: tensor(-35158092., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1590895.3750, grad_fn=<MulBackward0>)
# BCE is: tensor(-35811208., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1404916.8750, grad_fn=<MulBackward0>)
# BCE is: tensor(-37409668., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1256112.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-39245280., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1136200.3750, grad_fn=<MulBackward0>)
# BCE is: tensor(-39420732., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1039007.6250, grad_fn=<MulBackward0>)
# BCE is: tensor(-40186120., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(959775.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-42206056., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(894866., grad_fn=<MulBackward0>)
# -41311192.0
# Iter 29: BCE is: tensor(-35575384., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(268756.2812, grad_fn=<MulBackward0>)
# BCE is: tensor(-37044736., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(266336.8125, grad_fn=<MulBackward0>)
# BCE is: tensor(-37953440., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(265748.7188, grad_fn=<MulBackward0>)
# BCE is: tensor(-39313164., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(266689.8125, grad_fn=<MulBackward0>)
# BCE is: tensor(-40463648., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(268934.1562, grad_fn=<MulBackward0>)
# BCE is: tensor(-41261208., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(272261.0938, grad_fn=<MulBackward0>)
# BCE is: tensor(-42737432., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(276403.4688, grad_fn=<MulBackward0>)
# BCE is: tensor(-43989016., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(281119.5000, grad_fn=<MulBackward0>)
# -43707896.0
# Iter 30: BCE is: tensor(-12160712., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(206367.1250, grad_fn=<MulBackward0>)
# BCE is: tensor(-12414447., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(206653.2031, grad_fn=<MulBackward0>)
# BCE is: tensor(-12185118., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(207013.3594, grad_fn=<MulBackward0>)
# BCE is: tensor(-12862315., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(207521.7344, grad_fn=<MulBackward0>)
# BCE is: tensor(-13448038., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(208035.4062, grad_fn=<MulBackward0>)
# BCE is: tensor(-13618793., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(208523.2031, grad_fn=<MulBackward0>)
# BCE is: tensor(-14242637., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(209022.7031, grad_fn=<MulBackward0>)
# BCE is: tensor(-14235260., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(209588.1875, grad_fn=<MulBackward0>)
# -14025672.0
# Iter 31: BCE is: tensor(-38615816., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(47507560., grad_fn=<MulBackward0>)
# BCE is: tensor(-38766748., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(45152868., grad_fn=<MulBackward0>)
# BCE is: tensor(-38722428., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(41649472., grad_fn=<MulBackward0>)
# BCE is: tensor(-38682376., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(37504892., grad_fn=<MulBackward0>)
# BCE is: tensor(-38971624., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(33159336., grad_fn=<MulBackward0>)
# BCE is: tensor(-39772980., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(28934458., grad_fn=<MulBackward0>)
# BCE is: tensor(-39037436., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(25031770., grad_fn=<MulBackward0>)
# BCE is: tensor(-40253824., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(21551158., grad_fn=<MulBackward0>)
# -18702666.0
# Iter 32: BCE is: tensor(-41007048., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(265862.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-42553696., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(272236.9062, grad_fn=<MulBackward0>)
# BCE is: tensor(-44238332., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(281989.4688, grad_fn=<MulBackward0>)
# BCE is: tensor(-45817756., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(294922.9375, grad_fn=<MulBackward0>)
# BCE is: tensor(-47822048., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(310926.3125, grad_fn=<MulBackward0>)
# BCE is: tensor(-49622176., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(329596.1875, grad_fn=<MulBackward0>)
# BCE is: tensor(-51470588., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(349804.5938, grad_fn=<MulBackward0>)
# BCE is: tensor(-53773452., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(369932.6250, grad_fn=<MulBackward0>)
# -53403520.0
# Iter 33: BCE is: tensor(-38118004., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(265260.3438, grad_fn=<MulBackward0>)
# BCE is: tensor(-39324296., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(268470.2500, grad_fn=<MulBackward0>)
# BCE is: tensor(-40623048., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(272682.7812, grad_fn=<MulBackward0>)
# BCE is: tensor(-42012744., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(277414.2188, grad_fn=<MulBackward0>)
# BCE is: tensor(-42526908., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(282377.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-43613592., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(287114.7188, grad_fn=<MulBackward0>)
# BCE is: tensor(-44090056., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(291213.8438, grad_fn=<MulBackward0>)
# BCE is: tensor(-45327772., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(294351.5312, grad_fn=<MulBackward0>)
# -45033420.0
# Iter 34: BCE is: tensor(-39831936., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(9854925., grad_fn=<MulBackward0>)
# BCE is: tensor(-41015892., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(9047301., grad_fn=<MulBackward0>)
# BCE is: tensor(-42579960., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(8037267.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-43923464., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(6990629.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-45757936., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(6000669., grad_fn=<MulBackward0>)
# BCE is: tensor(-47042120., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(5114164., grad_fn=<MulBackward0>)
# BCE is: tensor(-48603624., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(4348218., grad_fn=<MulBackward0>)
# BCE is: tensor(-50162480., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3701826.2500, grad_fn=<MulBackward0>)
# -46460652.0
# Iter 35: BCE is: tensor(-32123080., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1404452.3750, grad_fn=<MulBackward0>)
# BCE is: tensor(-32575744., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1371825.3750, grad_fn=<MulBackward0>)
# BCE is: tensor(-32931280., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1342181.8750, grad_fn=<MulBackward0>)
# BCE is: tensor(-33749412., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1315037., grad_fn=<MulBackward0>)
# BCE is: tensor(-34704276., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1289941.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-34694588., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1266669.2500, grad_fn=<MulBackward0>)
# BCE is: tensor(-35142856., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1244955.3750, grad_fn=<MulBackward0>)
# BCE is: tensor(-35618892., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1224583.5000, grad_fn=<MulBackward0>)
# -34394308.0
# Iter 36: BCE is: tensor(-38605872., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(8624864., grad_fn=<MulBackward0>)
# BCE is: tensor(-39741648., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(7774194.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-41605552., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(6876604.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-43338268., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(6005816.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-44863768., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(5204742.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-46568488., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(4493711., grad_fn=<MulBackward0>)
# BCE is: tensor(-48096976., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3878120.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-49411580., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3353898.7500, grad_fn=<MulBackward0>)
# -46057680.0
# Iter 37: BCE is: tensor(-12485155., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(81335.4688, grad_fn=<MulBackward0>)
# BCE is: tensor(-12539875., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(81514.4766, grad_fn=<MulBackward0>)
# BCE is: tensor(-13198242., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(81940.0078, grad_fn=<MulBackward0>)
# BCE is: tensor(-13417038., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(82475.6406, grad_fn=<MulBackward0>)
# BCE is: tensor(-13364282., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(83072.3828, grad_fn=<MulBackward0>)
# BCE is: tensor(-13832688., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(83718.4609, grad_fn=<MulBackward0>)
# BCE is: tensor(-13958015., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(84393.2734, grad_fn=<MulBackward0>)
# BCE is: tensor(-14020038., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(85099.0859, grad_fn=<MulBackward0>)
# -13934939.0
# Iter 38: BCE is: tensor(-32820824., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1362803.1250, grad_fn=<MulBackward0>)
# BCE is: tensor(-33308016., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1349448.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-34192912., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1336267.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-34239024., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1323271.3750, grad_fn=<MulBackward0>)
# BCE is: tensor(-34668904., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1310471.8750, grad_fn=<MulBackward0>)
# BCE is: tensor(-35683864., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1297834.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-35622724., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1285386., grad_fn=<MulBackward0>)
# BCE is: tensor(-35532492., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1273120.5000, grad_fn=<MulBackward0>)
# -34259372.0
# Iter 39: BCE is: tensor(-41704664., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(278159.4375, grad_fn=<MulBackward0>)
# BCE is: tensor(-42207348., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(279643.6875, grad_fn=<MulBackward0>)
# BCE is: tensor(-42080688., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(283788.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-43562496., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(290940.3125, grad_fn=<MulBackward0>)
# BCE is: tensor(-44637960., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(301414.2500, grad_fn=<MulBackward0>)
# BCE is: tensor(-45857324., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(314788.9375, grad_fn=<MulBackward0>)
# BCE is: tensor(-47495440., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(330459.7188, grad_fn=<MulBackward0>)
# BCE is: tensor(-48779140., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(346163.0938, grad_fn=<MulBackward0>)
# -48432976.0
# Iter 40: BCE is: tensor(-38279804., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3201445.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-38588652., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3182117., grad_fn=<MulBackward0>)
# BCE is: tensor(-40803296., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3152729.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-41866228., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3114931.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-42005120., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3069872., grad_fn=<MulBackward0>)
# BCE is: tensor(-44235008., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3018237., grad_fn=<MulBackward0>)
# BCE is: tensor(-43863312., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2961638.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-44194272., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2901248.2500, grad_fn=<MulBackward0>)
# -41293024.0
# Iter 41: BCE is: tensor(-39634300., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(7360156., grad_fn=<MulBackward0>)
# BCE is: tensor(-40399048., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(7009362.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-41979096., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(6530705.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-42999944., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(5981859., grad_fn=<MulBackward0>)
# BCE is: tensor(-44478080., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(5409811.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-45761784., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(4848737.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-46494248., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(4320980., grad_fn=<MulBackward0>)
# BCE is: tensor(-47059320., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3839059.7500, grad_fn=<MulBackward0>)
# -43220260.0
# Iter 42: BCE is: tensor(-44583516., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2281834.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-46421024., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2240665.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-47488984., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2200596.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-48853764., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2161805.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-49298464., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2124660.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-51647432., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2089502.6250, grad_fn=<MulBackward0>)
# BCE is: tensor(-52644400., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2055898.8750, grad_fn=<MulBackward0>)
# BCE is: tensor(-53502708., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2023549.5000, grad_fn=<MulBackward0>)
# -51479160.0
# Iter 43: BCE is: tensor(-33987488., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1324158.3750, grad_fn=<MulBackward0>)
# BCE is: tensor(-34111136., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1301403.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-35104128., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1280087.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-35718560., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1259955.1250, grad_fn=<MulBackward0>)
# BCE is: tensor(-35845836., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1240733.3750, grad_fn=<MulBackward0>)
# BCE is: tensor(-36149312., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1222366.2500, grad_fn=<MulBackward0>)
# BCE is: tensor(-36205792., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1204747.6250, grad_fn=<MulBackward0>)
# BCE is: tensor(-36220736., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1187911., grad_fn=<MulBackward0>)
# -35032824.0
# Iter 44: BCE is: tensor(-31372220., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(442434.0625, grad_fn=<MulBackward0>)
# BCE is: tensor(-31844388., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(437074.7812, grad_fn=<MulBackward0>)
# BCE is: tensor(-32136918., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(432526.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-32393120., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(428713.5312, grad_fn=<MulBackward0>)
# BCE is: tensor(-32668368., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(425569.1250, grad_fn=<MulBackward0>)
# BCE is: tensor(-33532316., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(423062.1875, grad_fn=<MulBackward0>)
# BCE is: tensor(-33634436., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(421079.3438, grad_fn=<MulBackward0>)
# BCE is: tensor(-34090000., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(419507.3750, grad_fn=<MulBackward0>)
# -33670492.0
# Iter 45: BCE is: tensor(-43424332., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(14310885., grad_fn=<MulBackward0>)
# BCE is: tensor(-43502728., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(13956521., grad_fn=<MulBackward0>)
# BCE is: tensor(-45631096., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(13409149., grad_fn=<MulBackward0>)
# BCE is: tensor(-46957624., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(12721260., grad_fn=<MulBackward0>)
# BCE is: tensor(-48330336., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(11943178., grad_fn=<MulBackward0>)
# BCE is: tensor(-48951440., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(11119759., grad_fn=<MulBackward0>)
# BCE is: tensor(-49923464., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(10286904., grad_fn=<MulBackward0>)
# BCE is: tensor(-50179844., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(9472313., grad_fn=<MulBackward0>)
# -40707532.0
# Iter 46: BCE is: tensor(-17678776., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(232908.7812, grad_fn=<MulBackward0>)
# BCE is: tensor(-18004216., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(228749.2969, grad_fn=<MulBackward0>)
# BCE is: tensor(-18228368., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(225240.5156, grad_fn=<MulBackward0>)
# BCE is: tensor(-18706942., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(222244.0469, grad_fn=<MulBackward0>)
# BCE is: tensor(-18379914., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(219601.2812, grad_fn=<MulBackward0>)
# BCE is: tensor(-18816304., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(217338.6875, grad_fn=<MulBackward0>)
# BCE is: tensor(-18792222., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(215351.1250, grad_fn=<MulBackward0>)
# BCE is: tensor(-19152200., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(213601.0469, grad_fn=<MulBackward0>)
# -18938598.0
# Iter 47: BCE is: tensor(-13718346., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(71438., grad_fn=<MulBackward0>)
# BCE is: tensor(-13987842., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(71130.4922, grad_fn=<MulBackward0>)
# BCE is: tensor(-14436214., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(71021.9141, grad_fn=<MulBackward0>)
# BCE is: tensor(-15114859., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(71100.3906, grad_fn=<MulBackward0>)
# BCE is: tensor(-15208901., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(71358.0859, grad_fn=<MulBackward0>)
# BCE is: tensor(-15364867., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(71765.8281, grad_fn=<MulBackward0>)
# BCE is: tensor(-15693557., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(72316.8438, grad_fn=<MulBackward0>)
# BCE is: tensor(-15895765., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(72980.1953, grad_fn=<MulBackward0>)
# -15822785.0
# Iter 48: BCE is: tensor(-67490872., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1246322.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-69030512., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1240294., grad_fn=<MulBackward0>)
# BCE is: tensor(-69387272., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1236539.2500, grad_fn=<MulBackward0>)
# BCE is: tensor(-71887752., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1237160.8750, grad_fn=<MulBackward0>)
# BCE is: tensor(-73337520., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1241068.2500, grad_fn=<MulBackward0>)
# BCE is: tensor(-76603352., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1248010.2500, grad_fn=<MulBackward0>)
# BCE is: tensor(-77738848., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1255728.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-80201832., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1262715.8750, grad_fn=<MulBackward0>)
# -78939120.0
# Iter 49: BCE is: tensor(-46172240., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(290622.1562, grad_fn=<MulBackward0>)
# BCE is: tensor(-46240792., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(297211.9062, grad_fn=<MulBackward0>)
# BCE is: tensor(-46559776., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(305287.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-47644492., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(314461.6562, grad_fn=<MulBackward0>)
# BCE is: tensor(-48881956., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(324330.1875, grad_fn=<MulBackward0>)
# BCE is: tensor(-49968080., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(334463.5625, grad_fn=<MulBackward0>)
# BCE is: tensor(-50593744., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(344625.9375, grad_fn=<MulBackward0>)
# BCE is: tensor(-51640640., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(354443.4062, grad_fn=<MulBackward0>)
# -51286196.0
# Iter 50: BCE is: tensor(-55970664., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3018159.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-57189880., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3004068.5000, grad_fn=<MulBackward0>)
# ...
# KLD is: tensor(175478.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-15317433., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(174848.1719, grad_fn=<MulBackward0>)
# BCE is: tensor(-15036184., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(174274.0938, grad_fn=<MulBackward0>)
# BCE is: tensor(-16246393., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(173798.5469, grad_fn=<MulBackward0>)
# BCE is: tensor(-16199601., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(173444.0938, grad_fn=<MulBackward0>)
# BCE is: tensor(-16303730., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(173249.8906, grad_fn=<MulBackward0>)
# -16130480.0
# Iter 84: BCE is: tensor(-45490640., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(9482002., grad_fn=<MulBackward0>)
# BCE is: tensor(-45582080., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(9253090., grad_fn=<MulBackward0>)
# BCE is: tensor(-46583112., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(8905699., grad_fn=<MulBackward0>)
# BCE is: tensor(-47330816., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(8471016., grad_fn=<MulBackward0>)
# BCE is: tensor(-48135124., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(7979635., grad_fn=<MulBackward0>)
# BCE is: tensor(-48925224., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(7458539.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-49819952., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(6929799.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-50352544., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(6410267.5000, grad_fn=<MulBackward0>)
# -43942276.0
# Iter 85: BCE is: tensor(-78604120., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1081152.1250, grad_fn=<MulBackward0>)
# BCE is: tensor(-81668688., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1057614.6250, grad_fn=<MulBackward0>)
# BCE is: tensor(-81742256., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1037637.1250, grad_fn=<MulBackward0>)
# BCE is: tensor(-82860824., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1020867.0625, grad_fn=<MulBackward0>)
# BCE is: tensor(-84956112., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1006306.4375, grad_fn=<MulBackward0>)
# BCE is: tensor(-85137552., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(992862.3750, grad_fn=<MulBackward0>)
# BCE is: tensor(-86384936., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(979941.5625, grad_fn=<MulBackward0>)
# BCE is: tensor(-87193904., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(967091.6250, grad_fn=<MulBackward0>)
# -86226816.0
# Iter 86: BCE is: tensor(-46835716., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(795615.1250, grad_fn=<MulBackward0>)
# BCE is: tensor(-47185432., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(781691.3125, grad_fn=<MulBackward0>)
# BCE is: tensor(-47999544., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(770265.8750, grad_fn=<MulBackward0>)
# BCE is: tensor(-48673068., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(761874.1875, grad_fn=<MulBackward0>)
# BCE is: tensor(-49294336., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(756509.8750, grad_fn=<MulBackward0>)
# BCE is: tensor(-49866688., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(753775.4375, grad_fn=<MulBackward0>)
# BCE is: tensor(-50241044., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(752731.3750, grad_fn=<MulBackward0>)
# BCE is: tensor(-51363856., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(752027.8125, grad_fn=<MulBackward0>)
# -50611828.0
# Iter 87: BCE is: tensor(-17089196., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(159150.9844, grad_fn=<MulBackward0>)
# BCE is: tensor(-17258804., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(159357.3125, grad_fn=<MulBackward0>)
# BCE is: tensor(-17341136., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(159543., grad_fn=<MulBackward0>)
# BCE is: tensor(-17318102., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(159658.3594, grad_fn=<MulBackward0>)
# BCE is: tensor(-17399752., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(159673.1250, grad_fn=<MulBackward0>)
# BCE is: tensor(-17501680., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(159549.6875, grad_fn=<MulBackward0>)
# BCE is: tensor(-17671738., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(159281.6094, grad_fn=<MulBackward0>)
# BCE is: tensor(-17780468., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(158868.5312, grad_fn=<MulBackward0>)
# -17621600.0
# Iter 88: BCE is: tensor(-53033240., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1589028.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-53104332., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1577633.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-53988544., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1564489.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-54571368., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1550441.2500, grad_fn=<MulBackward0>)
# BCE is: tensor(-55596132., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1535549.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-55556708., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1519601.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-56766624., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1502626.6250, grad_fn=<MulBackward0>)
# BCE is: tensor(-56351864., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1484515., grad_fn=<MulBackward0>)
# -54867348.0
# Iter 89: BCE is: tensor(-48482560., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(282098.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-48927360., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(277548.2188, grad_fn=<MulBackward0>)
# BCE is: tensor(-49595040., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(273447.8125, grad_fn=<MulBackward0>)
# BCE is: tensor(-50470928., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(269936.7188, grad_fn=<MulBackward0>)
# BCE is: tensor(-50967112., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(267020.8750, grad_fn=<MulBackward0>)
# BCE is: tensor(-51760364., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(264820.3125, grad_fn=<MulBackward0>)
# BCE is: tensor(-52377168., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(263288.8750, grad_fn=<MulBackward0>)
# BCE is: tensor(-53191472., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(262335.9062, grad_fn=<MulBackward0>)
# -52929136.0
# Iter 90: BCE is: tensor(-49663096., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(330404.2812, grad_fn=<MulBackward0>)
# BCE is: tensor(-49893840., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(332814.6875, grad_fn=<MulBackward0>)
# BCE is: tensor(-50672000., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(335308.0938, grad_fn=<MulBackward0>)
# BCE is: tensor(-51067552., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(337811.9062, grad_fn=<MulBackward0>)
# BCE is: tensor(-51775408., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(340383.6250, grad_fn=<MulBackward0>)
# BCE is: tensor(-52362584., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(342967.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-53185816., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(345644.7188, grad_fn=<MulBackward0>)
# BCE is: tensor(-53946192., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(348357.7500, grad_fn=<MulBackward0>)
# -53597836.0
# Iter 91: BCE is: tensor(-47889972., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(795212.3750, grad_fn=<MulBackward0>)
# BCE is: tensor(-48911024., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(796242., grad_fn=<MulBackward0>)
# BCE is: tensor(-49667960., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(796737.1250, grad_fn=<MulBackward0>)
# BCE is: tensor(-49921024., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(796347.9375, grad_fn=<MulBackward0>)
# BCE is: tensor(-50331416., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(794896.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-50633432., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(792307.6250, grad_fn=<MulBackward0>)
# BCE is: tensor(-50837788., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(788775.1250, grad_fn=<MulBackward0>)
# BCE is: tensor(-51256184., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(784280.4375, grad_fn=<MulBackward0>)
# -50471904.0
# Iter 92: BCE is: tensor(-53416380., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(31770986., grad_fn=<MulBackward0>)
# BCE is: tensor(-53201680., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(30189418., grad_fn=<MulBackward0>)
# BCE is: tensor(-53525284., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(27580230., grad_fn=<MulBackward0>)
# BCE is: tensor(-54190284., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(24414594., grad_fn=<MulBackward0>)
# BCE is: tensor(-54386944., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(21104820., grad_fn=<MulBackward0>)
# BCE is: tensor(-54802520., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(17942786., grad_fn=<MulBackward0>)
# BCE is: tensor(-55226292., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(15096474., grad_fn=<MulBackward0>)
# BCE is: tensor(-55392216., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(12635128., grad_fn=<MulBackward0>)
# -42757088.0
# Iter 93: BCE is: tensor(-95560160., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1248871.1250, grad_fn=<MulBackward0>)
# BCE is: tensor(-97952264., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1195752., grad_fn=<MulBackward0>)
# BCE is: tensor(-99993704., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1156738.8750, grad_fn=<MulBackward0>)
# BCE is: tensor(-1.0169e+08, grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1127440.6250, grad_fn=<MulBackward0>)
# BCE is: tensor(-1.0397e+08, grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1103440., grad_fn=<MulBackward0>)
# BCE is: tensor(-1.0435e+08, grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1081875.6250, grad_fn=<MulBackward0>)
# BCE is: tensor(-1.0634e+08, grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1061114.6250, grad_fn=<MulBackward0>)
# BCE is: tensor(-1.0636e+08, grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1038965.7500, grad_fn=<MulBackward0>)
# -105317800.0
# Iter 94: BCE is: tensor(-39157136., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(352091.8750, grad_fn=<MulBackward0>)
# BCE is: tensor(-39972352., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(343924., grad_fn=<MulBackward0>)
# BCE is: tensor(-40048504., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(337560.6250, grad_fn=<MulBackward0>)
# BCE is: tensor(-40533136., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(332481.8125, grad_fn=<MulBackward0>)
# BCE is: tensor(-41070192., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(328376.0625, grad_fn=<MulBackward0>)
# BCE is: tensor(-41396432., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(325079.5938, grad_fn=<MulBackward0>)
# BCE is: tensor(-41880212., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(322258.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-42390164., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(319872.4375, grad_fn=<MulBackward0>)
# -42070292.0
# Iter 95: BCE is: tensor(-82579520., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1068302., grad_fn=<MulBackward0>)
# BCE is: tensor(-81720648., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1051026.2500, grad_fn=<MulBackward0>)
# BCE is: tensor(-82840072., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1035890.8750, grad_fn=<MulBackward0>)
# BCE is: tensor(-83402608., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1022413., grad_fn=<MulBackward0>)
# BCE is: tensor(-83011832., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1009796.8125, grad_fn=<MulBackward0>)
# BCE is: tensor(-83840440., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(997692.3125, grad_fn=<MulBackward0>)
# BCE is: tensor(-85519536., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(985760.2500, grad_fn=<MulBackward0>)
# BCE is: tensor(-85860672., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(973544.5625, grad_fn=<MulBackward0>)
# -84887128.0
# Iter 96: BCE is: tensor(-35132288., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(548682.5625, grad_fn=<MulBackward0>)
# BCE is: tensor(-35118840., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(543198.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-35252452., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(537838., grad_fn=<MulBackward0>)
# BCE is: tensor(-35389592., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(532608.9375, grad_fn=<MulBackward0>)
# BCE is: tensor(-35390584., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(527513.0625, grad_fn=<MulBackward0>)
# BCE is: tensor(-35546932., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(522645.4062, grad_fn=<MulBackward0>)
# BCE is: tensor(-35734888., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(517945.2188, grad_fn=<MulBackward0>)
# BCE is: tensor(-35858808., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(513360.4375, grad_fn=<MulBackward0>)
# -35345448.0
# Iter 97: BCE is: tensor(-44575636., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2047428.3750, grad_fn=<MulBackward0>)
# BCE is: tensor(-44154476., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2021111.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-44915180., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1990374.3750, grad_fn=<MulBackward0>)
# BCE is: tensor(-44846496., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1955971.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-45614872., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1918765.1250, grad_fn=<MulBackward0>)
# BCE is: tensor(-45585988., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1879492.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-45935672., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1838783.8750, grad_fn=<MulBackward0>)
# BCE is: tensor(-46031344., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1797201.5000, grad_fn=<MulBackward0>)
# -44234144.0
# Iter 98: BCE is: tensor(-17126790., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(157694.4375, grad_fn=<MulBackward0>)
# BCE is: tensor(-17246184., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(154968.7656, grad_fn=<MulBackward0>)
# BCE is: tensor(-17332906., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(152592.0938, grad_fn=<MulBackward0>)
# BCE is: tensor(-17396356., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(150538.5312, grad_fn=<MulBackward0>)
# BCE is: tensor(-17582032., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(148788.3438, grad_fn=<MulBackward0>)
# BCE is: tensor(-17666452., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(147301.8594, grad_fn=<MulBackward0>)
# BCE is: tensor(-17966060., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(146030.2812, grad_fn=<MulBackward0>)
# BCE is: tensor(-18015688., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(144917.0781, grad_fn=<MulBackward0>)
# -17870770.0
# Iter 99: BCE is: tensor(-53526564., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(356508.1250, grad_fn=<MulBackward0>)
# BCE is: tensor(-53500836., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(356785.9375, grad_fn=<MulBackward0>)
# BCE is: tensor(-54574488., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(359203.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-55255504., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(363399.6562, grad_fn=<MulBackward0>)
# BCE is: tensor(-56688376., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(369128.8125, grad_fn=<MulBackward0>)
# BCE is: tensor(-57838696., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(375931.8125, grad_fn=<MulBackward0>)
# BCE is: tensor(-58262660., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(383080.7812, grad_fn=<MulBackward0>)
# BCE is: tensor(-59720632., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(390710.8750, grad_fn=<MulBackward0>)
# -59329920.0

# %%
# Second train after meta training

pretrained_model = load_model('saved_models/temp.pt', ToyVAE)

# %%
import numpy as np
import matplotlib.pyplot as plt

from env import sr
from transform import log_stft, db_to_amp
from dataset import read_audio, TaskDataset, InputData
from visualization import plot_spec
from vocoder import griffin_lim


def sound(x, rate=sr, label=''):
    from IPython.display import display, Audio, HTML
    display(HTML(
        '<style> table, th, td {border: 0px; }</style> <table><tr><td>'
        + label + '</td><td>' + Audio(x, rate=rate)._repr_html_()[3:]
        + '</td></tr></table>'
    ))


def test(c, train_source_filename, train_target_filename,
         test_input_filename):
    def plot_selected_frames(selected_frames):
        plt.twinx()
        plt.scatter(np.arange(selected_frames.size), selected_frames)

    task_dat = TaskDataset(train_source_filename, train_target_filename)
    input_dat = InputData(test_input_filename)
    plot_spec(log_stft(task_dat.source.amp), title='Source train')
    plot_selected_frames(task_dat.source.selected_frames)
    sound(read_audio(train_source_filename), label='Source train')
    plot_spec(log_stft(task_dat.target.amp), title='Target train')
    plot_selected_frames(task_dat.target.selected_frames)
    sound(read_audio(train_target_filename), label='Target train')

    train_x, train_y = task_dat.get()
    plot_spec(train_x, title='Source train aligned')
    sound(griffin_lim(db_to_amp(train_x)), label='Source train aligned')

    plot_spec(train_y, title='Target train aligned')
    sound(griffin_lim(db_to_amp(train_y)), label='Target train aligned')

    train_x, train_y = torch.from_numpy(train_x), torch.from_numpy(train_y)
    train(model, train_x, train_y, n_inner_loop=20)

    x = input_dat.get()
    x = torch.from_numpy(x.T)
    estimated_tuple = model(x)
    estimated = estimated_tuple[0]
    y = estimated.detach().numpy().T
    plot_spec(log_stft(input_dat.dat.amp), title='Test source')
    sound(read_audio(test_input_filename), label='Test source')
    plot_spec(y, title='Test output')
    sound(griffin_lim(db_to_amp(y)), label='Test source')


meta_dat = SanityMetadata()

test(pretrained_model, meta_dat.get(0, 0), meta_dat.get(1, 0),
     meta_dat.get(0, 1))
# Out:
# <style> table, th, td {border: 0px; }</style> <table><tr><td>Source train</td><td>              <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#               </td></tr></table>
# <style> table, th, td {border: 0px; }</style> <table><tr><td>Target train</td><td>              <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#               </td></tr></table>
# <style> table, th, td {border: 0px; }</style> <table><tr><td>Source train aligned</td><td>              <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#               </td></tr></table>
# <style> table, th, td {border: 0px; }</style> <table><tr><td>Target train aligned</td><td>              <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#               </td></tr></table>
# BCE is: tensor(-44020800., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(4199453.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-44895928., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(4097241.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-45717112., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3922068.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-46833592., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3695088.5000, grad_fn=<MulBackward0>)
# BCE is: tensor(-47640096., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3436519.2500, grad_fn=<MulBackward0>)
# BCE is: tensor(-48278728., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(3164037., grad_fn=<MulBackward0>)
# BCE is: tensor(-48688344., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2891565.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-49213904., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2629122.2500, grad_fn=<MulBackward0>)
# BCE is: tensor(-49535120., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2383260.2500, grad_fn=<MulBackward0>)
# BCE is: tensor(-49867352., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(2158440.2500, grad_fn=<MulBackward0>)
# BCE is: tensor(-49424980., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1976837.6250, grad_fn=<MulBackward0>)
# BCE is: tensor(-50378944., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1770671.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-50260296., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1608480.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-50640472., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1465605.6250, grad_fn=<MulBackward0>)
# BCE is: tensor(-50725248., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1340097.7500, grad_fn=<MulBackward0>)
# BCE is: tensor(-50966404., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1230105., grad_fn=<MulBackward0>)
# BCE is: tensor(-50990752., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1133778.6250, grad_fn=<MulBackward0>)
# BCE is: tensor(-51236588., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(1049375.6250, grad_fn=<MulBackward0>)
# BCE is: tensor(-51386928., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(975356.9375, grad_fn=<MulBackward0>)
# BCE is: tensor(-51373576., grad_fn=<BinaryCrossEntropyBackward>)
# KLD is: tensor(910467.1250, grad_fn=<MulBackward0>)
# -50463108.0
# <style> table, th, td {border: 0px; }</style> <table><tr><td>Test source</td><td>              <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#               </td></tr></table>
# <style> table, th, td {border: 0px; }</style> <table><tr><td>Test source</td><td>              <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#               </td></tr></table>

# %%
# test with actual samples
